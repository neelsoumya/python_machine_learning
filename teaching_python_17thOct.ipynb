# %% [markdown]
# <a href="https://colab.research.google.com/github/neelsoumya/python_machine_learning/blob/main/teaching_python_17thOct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unsupervised machine learning practical Day 1 17th October 2025
#
# * Introduction to Python
# * PCA
# * tSNE

# %%
# !pip install pandas numpy scikit-learn seaborn matplotlib scanpy pca
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.12/dist-packages (1.11.4)
# Requirement already satisfied: pca in /usr/local/lib/python3.12/dist-packages (2.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: anndata>=0.8 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.12.3)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.14.0)
# Requirement already satisfied: legacy-api-wrap>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.4.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.5)
# Requirement already satisfied: numba>=0.57.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.13)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.2.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.9.post2)
# Requirement already satisfied: datazets in /usr/local/lib/python3.12/dist-packages (from pca) (1.1.3)
# Requirement already satisfied: colourmap>=1.1.19 in /usr/local/lib/python3.12/dist-packages (from pca) (1.2.0)
# Requirement already satisfied: scatterd>=1.3.7 in /usr/local/lib/python3.12/dist-packages (from pca) (1.4.1)
# Requirement already satisfied: adjusttext in /usr/local/lib/python3.12/dist-packages (from pca) (1.3.0)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.8->scanpy) (1.12.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.8->scanpy) (3.1.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.57.1->scanpy) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from datazets->pca) (2.32.4)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (0.16.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (2025.10.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.3)
# Requirement already satisfied: crc32c>=2.7 in /usr/local/lib/python3.12/dist-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (2.8)

# %% [markdown]
# # Load data

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load data into pandas

# %%
github_url = "https://raw.githubusercontent.com/cambiotraining/ml-unsupervised/main/course_files/data/diabetes_sample_data.csv"

# read data
diabetes_data = pd.read_csv(github_url)

print(diabetes_data.head())
# Out:
#    patient_id   age  glucose   bmi  blood_pressure  diabetes
# 0           1  62.5     97.5  29.8            71.7         0
# 1           2  52.9    127.4  30.8            74.4         0
# 2           3  64.7    129.7  33.4            87.5         0
# 3           4  77.8    115.9  33.3            86.1         1
# 4           5  51.5    135.2  21.1            79.8         1

# %% [markdown]
# # PLotting

# %%
plt.figure()
plt.hist(diabetes_data['age'])
plt.show()

# %% [markdown]
# # Do PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load new data

# %%
url = "https://raw.githubusercontent.com/cambiotraining/ml-unsupervised/main/course_files/data/USArrests.csv"
X = pd.read_csv(url, index_col=0)

print(X.head())
# Out:
#             Murder  Assault  UrbanPop  Rape
# State
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %% [markdown]
# # Normalize the data

# %%
scaler_standard = StandardScaler()
X_scaled = scaler_standard.fit_transform(X)

print(X_scaled)
#  [-3.66423378e-01  2.92555039e-01 -2.64151823e-02 -1.28460014e-02]
#  [ 3.27565221e-03  5.56211571e-01  9.21911529e-01  2.36698192e-01]
#  [-9.41352959e-01  5.68485538e-01 -4.11608308e-01 -3.64358218e-01]
#  [-9.09908548e-01  1.46494762e+00 -1.38773128e+00  6.00086501e-01]
#  [ 1.25731005e+00 -1.91475600e+00 -2.90120668e-01  1.41580049e-01]
#  [-2.03888390e+00 -7.78125150e-01  3.75435428e-01  1.09319380e-01]
#  [ 9.35690273e-01 -8.51392121e-01  1.92734424e-01 -6.45742668e-01]
#  [ 1.29326852e+00  3.87317186e-01 -4.90483854e-01 -6.42740050e-01]
#  [-6.02261688e-01  1.46634217e+00  2.71829552e-01  7.44688909e-02]
#  [-2.85133656e+00 -1.33266483e+00  8.25094455e-01  1.46559115e-01]
#  [-1.53441329e-01 -1.90521171e-01  5.75076136e-03 -2.10782758e-01]
#  [-2.70617314e-01  9.75724355e-01  6.04878018e-01  2.16519249e-01]
#  [-2.16093291e+00 -1.37560856e+00  9.73366404e-02 -1.29911492e-01]]

# %% [markdown]
# # Plot biplot

# %%
plt.figure()
plt.scatter(X_pca[:,0], X_pca[:,1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Biplot")
plt.show()

# %% [markdown]
# # Categorical variables

# %%
print(X.index)

states = X.index

state_codes = pd.Categorical(states).codes

plt.figure()
plt.scatter(X_pca[:,0], X_pca[:,1], c=state_codes)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA biplot")
plt.show()
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia'],
#       dtype='object', name='State')

# %% [markdown]
# # getting labels

# %%
plt.figure()
plt.scatter(X_pca[:,0], X_pca[:,1], alpha = 0.7)
plt.show()

plt.figure()
plt.scatter(X_pca[:,0,], X_pca[:,1], alpha = 0.7)

print(X.index)
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia'],
#       dtype='object', name='State')

# %% [markdown]
# # definitive code to plot text

# %%
fig, ax = plt.subplots()

ax.scatter(X_pca[:,0], X_pca[:,1])

for i, state in enumerate(X.index):
  ax.text(X_pca[i,0], X_pca[i,1], state, fontsize = 6)

ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_title("PCA biplot with text")

plt.show()

# %% [markdown]
# # getting the loadings

# %%
print(pca_fn.components_.T)

loadings = pca_fn.components_.T

pd.DataFrame(loadings,
             index = X.columns
             )
# Out:
# [[ 0.53378466 -0.42876457 -0.33192724 -0.64889074]
#  [ 0.58348892 -0.1904847  -0.26759253  0.74273178]
#  [ 0.28421258  0.86595013 -0.38678356 -0.14054203]
#  [ 0.5420681   0.17322499  0.81769005 -0.0868231 ]]
#                  0         1         2         3
# Murder    0.533785 -0.428765 -0.331927 -0.648891
# Assault   0.583489 -0.190485 -0.267593  0.742732
# UrbanPop  0.284213  0.865950 -0.386784 -0.140542
# Rape      0.542068  0.173225  0.817690 -0.086823

# %% [markdown]
# # Using the PCA package

# %%
from pca import pca

url = "https://raw.githubusercontent.com/cambiotraining/ml-unsupervised/main/course_files/data/USArrests.csv"

df = pd.read_csv(url, index_col=0)

print(df.head())
# Out:
#             Murder  Assault  UrbanPop  Rape
# State
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %% [markdown]
# # Normalize and perform PCA

# %%
model = pca(normalize = True)

out = model.fit_transform(df)

ax = model.biplot()
# Out:
# [17-10-2025 16:16:21] [pca.pca] [INFO] Extracting column labels from dataframe.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Extracting row labels from dataframe.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Normalizing input data per feature (zero mean and unit variance)..
# [17-10-2025 16:16:21] [pca.pca] [INFO] PCA reduction performed to capture 95.0% explained variance using 4 columns of the input data.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Fit using PCA.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Compute loadings and PCs.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Compute explained variance.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Number of components is 3 that covers 95.00% explained variance.
# [17-10-2025 16:16:21] [pca.pca] [INFO] The PCA reduction is performed on the 4 columns of the input dataframe.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Fit using PCA.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Compute loadings and PCs.
# [17-10-2025 16:16:21] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[3]
# [17-10-2025 16:16:21] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [17-10-2025 16:16:21] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]
# [17-10-2025 16:16:21] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [17-10-2025 16:16:21] [scatterd.scatterd] [INFO] Create scatterplot

# %% [markdown]
# # loadings

# %%
print(model.results)
# Out:
# {'loadings':        Murder   Assault  UrbanPop      Rape
# PC1  0.533785  0.583489  0.284213  0.542068
# PC2 -0.428765 -0.190485  0.865950  0.173225
# PC3 -0.331927 -0.267593 -0.386784  0.817690, 'PC':                      PC1       PC2       PC3
# Alabama         0.923886 -1.127792 -0.437720
# Alaska          1.884005 -1.032585  2.032973
# Arizona         1.705462  0.730059  0.043498
# Arkansas       -0.198714 -1.092074  0.111217
# California      2.462479  1.513698  0.585558
# Colorado        1.453427  0.982671  1.080932
# Connecticut    -1.406810  1.081895 -0.661238
# Delaware       -0.003621  0.319738 -0.730442
# Florida         2.947649 -0.070435 -0.569823
# Georgia         1.571384 -1.281416 -0.326932
# Hawaii         -0.966398  1.557165  0.034386
# Idaho          -1.689257 -0.178154  0.241665
# Illinois        1.320695  0.653978 -0.681444
# Indiana        -0.561650  0.161720  0.218372
# Iowa           -2.302281  0.133259  0.145716
# Kansas         -0.850716  0.279295  0.013602
# Kentucky       -0.808869 -0.934920 -0.029023
# Louisiana       1.500981 -0.882536 -0.772483
# Maine          -2.444195 -0.340245 -0.083049
# Maryland        1.702710 -0.431039 -0.158134
# Massachusetts  -0.536401  1.454143 -0.626920
# Michigan        2.044350  0.144860  0.383014
# Minnesota      -1.742422  0.647555  0.133541
# Mississippi     0.932617 -2.374555 -0.724196
# Missouri        0.637255  0.263934  0.369919
# Montana        -1.239466 -0.507562  0.236769
# Nebraska       -1.317489  0.212450  0.160150
# Nevada          2.806905  0.760007  1.157898
# New Hampshire  -2.431886  0.048021  0.018380
# New Jersey      0.127587  1.417883 -0.775421
# New Mexico      1.917815 -0.148279  0.181459
# New York        1.623118  0.790157 -0.646164
# North Carolina  1.064086 -2.207350 -0.854340
# North Dakota   -3.038797 -0.548177  0.281399
# Ohio           -0.281823  0.736114 -0.041732
# Oklahoma       -0.366423  0.292555 -0.026415
# Oregon          0.003276  0.556212  0.921912
# Pennsylvania   -0.941353  0.568486 -0.411608
# Rhode Island   -0.909909  1.464948 -1.387731
# South Carolina  1.257310 -1.914756 -0.290121
# South Dakota   -2.038884 -0.778125  0.375435
# Tennessee       0.935690 -0.851392  0.192734
# Texas           1.293269  0.387317 -0.490484
# Utah           -0.602262  1.466342  0.271830
# Vermont        -2.851337 -1.332665  0.825094
# Virginia       -0.153441 -0.190521  0.005751
# Washington     -0.270617  0.975724  0.604878
# West Virginia  -2.160933 -1.375609  0.097337, 'explained_var': array([0.61629429, 0.86387677, 0.95532444, 1.        ]), 'variance_ratio': array([0.61629429, 0.24758248, 0.09144767, 0.04467556]), 'model': PCA(n_components=np.int64(3)), 'scaler': StandardScaler(), 'pcp': np.float64(1.0000000000000002), 'topfeat':     PC   feature   loading  type
# 0  PC1   Assault  0.583489  best
# 1  PC2  UrbanPop  0.865950  best
# 2  PC3      Rape  0.817690  best
# 3  PC1    Murder  0.533785  weak, 'outliers':                  y_proba     p_raw    y_score  y_bool  y_bool_spe  y_score_spe
# Alabama         0.883607  0.572223   4.780770   False       False     1.457903
# Alaska          0.771864  0.061516  12.020355   False       False     2.148419
# Arizona         0.883607  0.487777   5.447889   False       False     1.855152
# Arkansas        0.994964  0.849865   2.662427   False       False     1.110005
# California      0.771864  0.073767  11.512662   False       False     2.890516
# Colorado        0.883607  0.291940   7.323773   False       False     1.754449
# Connecticut     0.883607  0.376298   6.434671   False       False     1.774715
# Delaware        0.997194  0.934870   1.827387   False       False     0.319759
# Florida         0.827974  0.105185  10.498050   False       False     2.948491
# Georgia         0.883607  0.334106   6.858767   False       False     2.027628
# Hawaii          0.883607  0.482129   5.494442   False       False     1.832672
# Idaho           0.883607  0.589071   4.652640   False       False     1.698626
# Illinois        0.883607  0.518417   5.200102   False       False     1.473744
# Indiana         0.997522  0.957121   1.535211   False       False     0.584469
# Iowa            0.883607  0.341171   6.785183   False       False     2.306135
# Kansas          0.997194  0.915334   2.046914   False       False     0.895390
# Kentucky        0.942972  0.766164   3.332046   False       False     1.236262
# Louisiana       0.883607  0.372576   6.470687   False       False     1.741210
# Maine           0.883607  0.264681   7.652531   False       False     2.467763
# Maryland        0.883607  0.543590   5.001739   False       False     1.756421
# Massachusetts   0.883607  0.512543   5.247023   False       False     1.549922
# Michigan        0.883607  0.406682   6.149239   False       False     2.049476
# Minnesota       0.883607  0.477475   5.533020   False       False     1.858861
# Mississippi     0.827974  0.134373   9.776761   False       False     2.551134
# Missouri        0.997194  0.908446   2.118885   False       False     0.689750
# Montana         0.942972  0.701130   3.819185   False       False     1.339364
# Nebraska        0.942972  0.758317   3.391711   False       False     1.334509
# Nevada          0.771864  0.052403  12.462954   False       False     2.907976
# New Hampshire   0.883607  0.317979   7.031119   False       False     2.432360
# New Jersey      0.883607  0.577856   4.737795   False       False     1.423612
# New Mexico      0.883607  0.502690   5.326337   False       False     1.923539
# New York        0.883607  0.382425   6.375898   False       False     1.805231
# North Carolina  0.827974  0.137996   9.697217   False       False     2.450444
# North Dakota    0.771864  0.080403  11.269266   False       False     3.087845
# Ohio            0.997194  0.934716   1.829224   False       False     0.788218
# Oklahoma        0.997522  0.982272   1.082928   False       False     0.468886
# Oregon          0.994964  0.843369   2.717557   False       False     0.556221
# Pennsylvania    0.942972  0.749878   3.455517   False       False     1.099691
# Rhode Island    0.883607  0.234460   8.050041   False       False     1.724530
# South Carolina  0.883607  0.243404   7.928295   False       False     2.290659
# South Dakota    0.883607  0.291991   7.323178   False       False     2.182321
# Tennessee       0.942972  0.719456   3.683208   False       False     1.265063
# Texas           0.942972  0.649265   4.202711   False       False     1.350022
# Utah            0.883607  0.576700   4.746601   False       False     1.585206
# Vermont         0.771864  0.038043  13.332939   False       False     3.147398
# Virginia        0.997522  0.997522   0.524914   False       False     0.244627
# Washington      0.942972  0.761722   3.365861   False       False     1.012557
# West Virginia   0.883607  0.177782   8.926009   False       False     2.561626, 'outliers_params': {'paramT2': (np.float64(6.1679056923619804e-18), np.float64(1.273765915366402)), 'paramSPE': (array([-5.55111512e-17,  4.62592927e-18]), array([[ 2.51762774e+00, -5.98385509e-17],
#        [-5.98385509e-17,  1.01140077e+00]]))}}

# %%
# Extract the desired keys and convert them to DataFrames
loadings_df = pd.DataFrame(model.results['loadings'])
pc_df = pd.DataFrame(model.results['PC'])
explained_var_df = pd.DataFrame({'explained_variance': model.results['explained_var']})
variance_ratio_df = pd.DataFrame({'variance_ratio': model.results['variance_ratio']})
topfeat_df = pd.DataFrame(model.results['topfeat'])
outliers_df = pd.DataFrame(model.results['outliers'])

# Display the DataFrames
print("Loadings DataFrame:")
display(loadings_df)

print("\nPrincipal Components DataFrame:")
display(pc_df)

print("\nExplained Variance DataFrame:")
display(explained_var_df)

print("\nVariance Ratio DataFrame:")
display(variance_ratio_df)

print("\nTop Features DataFrame:")
display(topfeat_df)

print("\nOutliers DataFrame:")
display(outliers_df)
# Out:
# Loadings DataFrame:
#        Murder   Assault  UrbanPop      Rape
# PC1  0.533785  0.583489  0.284213  0.542068
# PC2 -0.428765 -0.190485  0.865950  0.173225
# PC3 -0.331927 -0.267593 -0.386784  0.817690
# Principal Components DataFrame:
#                      PC1       PC2       PC3
# Alabama         0.923886 -1.127792 -0.437720
# Alaska          1.884005 -1.032585  2.032973
# Arizona         1.705462  0.730059  0.043498
# Arkansas       -0.198714 -1.092074  0.111217
# California      2.462479  1.513698  0.585558
# Colorado        1.453427  0.982671  1.080932
# Connecticut    -1.406810  1.081895 -0.661238
# Delaware       -0.003621  0.319738 -0.730442
# Florida         2.947649 -0.070435 -0.569823
# Georgia         1.571384 -1.281416 -0.326932
# Hawaii         -0.966398  1.557165  0.034386
# Idaho          -1.689257 -0.178154  0.241665
# Illinois        1.320695  0.653978 -0.681444
# Indiana        -0.561650  0.161720  0.218372
# Iowa           -2.302281  0.133259  0.145716
# Kansas         -0.850716  0.279295  0.013602
# Kentucky       -0.808869 -0.934920 -0.029023
# Louisiana       1.500981 -0.882536 -0.772483
# Maine          -2.444195 -0.340245 -0.083049
# Maryland        1.702710 -0.431039 -0.158134
# Massachusetts  -0.536401  1.454143 -0.626920
# Michigan        2.044350  0.144860  0.383014
# Minnesota      -1.742422  0.647555  0.133541
# Mississippi     0.932617 -2.374555 -0.724196
# Missouri        0.637255  0.263934  0.369919
# Montana        -1.239466 -0.507562  0.236769
# Nebraska       -1.317489  0.212450  0.160150
# Nevada          2.806905  0.760007  1.157898
# New Hampshire  -2.431886  0.048021  0.018380
# New Jersey      0.127587  1.417883 -0.775421
# New Mexico      1.917815 -0.148279  0.181459
# New York        1.623118  0.790157 -0.646164
# North Carolina  1.064086 -2.207350 -0.854340
# North Dakota   -3.038797 -0.548177  0.281399
# Ohio           -0.281823  0.736114 -0.041732
# Oklahoma       -0.366423  0.292555 -0.026415
# Oregon          0.003276  0.556212  0.921912
# Pennsylvania   -0.941353  0.568486 -0.411608
# Rhode Island   -0.909909  1.464948 -1.387731
# South Carolina  1.257310 -1.914756 -0.290121
# South Dakota   -2.038884 -0.778125  0.375435
# Tennessee       0.935690 -0.851392  0.192734
# Texas           1.293269  0.387317 -0.490484
# Utah           -0.602262  1.466342  0.271830
# Vermont        -2.851337 -1.332665  0.825094
# Virginia       -0.153441 -0.190521  0.005751
# Washington     -0.270617  0.975724  0.604878
# West Virginia  -2.160933 -1.375609  0.097337
# Explained Variance DataFrame:
#    explained_variance
# 0            0.616294
# 1            0.863877
# 2            0.955324
# 3            1.000000
# Variance Ratio DataFrame:
#    variance_ratio
# 0        0.616294
# 1        0.247582
# 2        0.091448
# 3        0.044676
# Top Features DataFrame:
#     PC   feature   loading  type
# 0  PC1   Assault  0.583489  best
# 1  PC2  UrbanPop  0.865950  best
# 2  PC3      Rape  0.817690  best
# 3  PC1    Murder  0.533785  weak
# Outliers DataFrame:
#                  y_proba     p_raw    y_score  y_bool  y_bool_spe  y_score_spe
# Alabama         0.883607  0.572223   4.780770   False       False     1.457903
# Alaska          0.771864  0.061516  12.020355   False       False     2.148419
# Arizona         0.883607  0.487777   5.447889   False       False     1.855152
# Arkansas        0.994964  0.849865   2.662427   False       False     1.110005
# California      0.771864  0.073767  11.512662   False       False     2.890516
# Colorado        0.883607  0.291940   7.323773   False       False     1.754449
# Connecticut     0.883607  0.376298   6.434671   False       False     1.774715
# Delaware        0.997194  0.934870   1.827387   False       False     0.319759
# Florida         0.827974  0.105185  10.498050   False       False     2.948491
# Georgia         0.883607  0.334106   6.858767   False       False     2.027628
# Hawaii          0.883607  0.482129   5.494442   False       False     1.832672
# Idaho           0.883607  0.589071   4.652640   False       False     1.698626
# Illinois        0.883607  0.518417   5.200102   False       False     1.473744
# Indiana         0.997522  0.957121   1.535211   False       False     0.584469
# Iowa            0.883607  0.341171   6.785183   False       False     2.306135
# Kansas          0.997194  0.915334   2.046914   False       False     0.895390
# Kentucky        0.942972  0.766164   3.332046   False       False     1.236262
# Louisiana       0.883607  0.372576   6.470687   False       False     1.741210
# Maine           0.883607  0.264681   7.652531   False       False     2.467763
# Maryland        0.883607  0.543590   5.001739   False       False     1.756421
# Massachusetts   0.883607  0.512543   5.247023   False       False     1.549922
# Michigan        0.883607  0.406682   6.149239   False       False     2.049476
# Minnesota       0.883607  0.477475   5.533020   False       False     1.858861
# Mississippi     0.827974  0.134373   9.776761   False       False     2.551134
# Missouri        0.997194  0.908446   2.118885   False       False     0.689750
# Montana         0.942972  0.701130   3.819185   False       False     1.339364
# Nebraska        0.942972  0.758317   3.391711   False       False     1.334509
# Nevada          0.771864  0.052403  12.462954   False       False     2.907976
# New Hampshire   0.883607  0.317979   7.031119   False       False     2.432360
# New Jersey      0.883607  0.577856   4.737795   False       False     1.423612
# New Mexico      0.883607  0.502690   5.326337   False       False     1.923539
# New York        0.883607  0.382425   6.375898   False       False     1.805231
# North Carolina  0.827974  0.137996   9.697217   False       False     2.450444
# North Dakota    0.771864  0.080403  11.269266   False       False     3.087845
# Ohio            0.997194  0.934716   1.829224   False       False     0.788218
# Oklahoma        0.997522  0.982272   1.082928   False       False     0.468886
# Oregon          0.994964  0.843369   2.717557   False       False     0.556221
# Pennsylvania    0.942972  0.749878   3.455517   False       False     1.099691
# Rhode Island    0.883607  0.234460   8.050041   False       False     1.724530
# South Carolina  0.883607  0.243404   7.928295   False       False     2.290659
# South Dakota    0.883607  0.291991   7.323178   False       False     2.182321
# Tennessee       0.942972  0.719456   3.683208   False       False     1.265063
# Texas           0.942972  0.649265   4.202711   False       False     1.350022
# Utah            0.883607  0.576700   4.746601   False       False     1.585206
# Vermont         0.771864  0.038043  13.332939   False       False     3.147398
# Virginia        0.997522  0.997522   0.524914   False       False     0.244627
# Washington      0.942972  0.761722   3.365861   False       False     1.012557
# West Virginia   0.883607  0.177782   8.926009   False       False     2.561626

# %% [markdown]
# # scree plots

# %%
model.plot()
# Out:
# (<Figure size 1500x1000 with 1 Axes>,
#  <Axes: title={'center': 'Cumulative explained variance\n 3 Principal Components explain [100.0%] of the variance.'}, xlabel='Principal Component', ylabel='Percentage explained variance'>)

# %% [markdown]
# # tSNE practical

# %% [markdown]
# # Load packages

# %%
from sklearn.manifold import TSNE
from sklearn import datasets

# %%
# load the iris data
iris = datasets.load_iris()

X = iris.data
#print(X)

# %% [markdown]
# # Perform tSNE

# %%
tsne = TSNE(n_components = 2, perplexity=30)
X_2d = tsne.fit_transform(X)

y = iris.target

# %% [markdown]
# # Plot

# %%
plt.figure()
plt.scatter(X_2d[:,0], X_2d[:,1], c = y)
plt.show()
