# %% [markdown]
# <a href="https://colab.research.google.com/github/neelsoumya/python_machine_learning/blob/main/teaching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template code for Google Colab

# %%
from google.colab import drive
import os

# %%
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/ml-unsupervised/course_files/data')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load data

# %%
import pandas as pd

pd.read_csv('diabetes_sample_data.csv')
# Out:
#     patient_id   age  glucose   bmi  blood_pressure  diabetes
# 0            1  62.5     97.5  29.8            71.7         0
# 1            2  52.9    127.4  30.8            74.4         0
# 2            3  64.7    129.7  33.4            87.5         0
# 3            4  77.8    115.9  33.3            86.1         1
# 4            5  51.5    135.2  21.1            79.8         1
# ..         ...   ...      ...   ...             ...       ...
# 95          96  33.0    151.6  24.5            75.3         0
# 96          97  59.4    113.5  32.5            62.9         0
# 97          98  58.9    144.6  29.5            93.5         0
# 98          99  55.1    141.7  32.1            78.9         0
# 99         100  51.5    105.7  31.1            92.4         0
#
# [100 rows x 6 columns]
